# %%
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup
import requests

# %%
page = requests.get('https://musicbrainz.org/series/8668518f-4a1e-4802-8b0d-81703ced6418?page=1')

# %%
page.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
list(soup.children)
# Out:
# ['html',
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Rolling Stone: 500 Greatest Albums of All Time: 2012 edition - MusicBrainz
#   </title>
#   <link href="https://staticbrainz.org/MB/common-be35946.css" rel="stylesheet" type="text/css"/>
#   <link href="https://staticbrainz.org/MB/icons-275fe45.css" rel="stylesheet" type="text/css"/>
#   <link href="/static/search_plugins/opensearch/musicbrainz_artist.xml" rel="search" title="MusicBrainz: Artist" type="application/opensearchdescription+xml"/>
#   <link href="/static/search_plugins/opensearch/musicbrainz_label.xml" rel="search" title="MusicBrainz: Label" type="application/opensearchdescription+xml"/>
#   <link href="/static/search_plugins/opensearch/musicbrainz_release.xml" rel="search" title="MusicBrainz: Release" type="application/opensearchdescription+xml"/>
# ...
