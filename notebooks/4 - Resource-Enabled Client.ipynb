# %% [markdown]
# ### Spotify doesn't have it's own API Client. So I have to make one myself.
# ##### The goal is to make a reusable client id

# %%
! pip install requests
# Out:
# Requirement already satisfied: requests in /Users/andrewlowe/.local/share/virtualenvs/Spotify_Personal_Project-FylsQ0Dk/lib/python3.7/site-packages (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/andrewlowe/.local/share/virtualenvs/Spotify_Personal_Project-FylsQ0Dk/lib/python3.7/site-packages (from requests) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/andrewlowe/.local/share/virtualenvs/Spotify_Personal_Project-FylsQ0Dk/lib/python3.7/site-packages (from requests) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/andrewlowe/.local/share/virtualenvs/Spotify_Personal_Project-FylsQ0Dk/lib/python3.7/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /Users/andrewlowe/.local/share/virtualenvs/Spotify_Personal_Project-FylsQ0Dk/lib/python3.7/site-packages (from requests) (2.10)

# %%
import base64
import requests
import datetime
from urllib.parse import urlencode

# %%
client_id = "fcbebafbe040467782d5a4ce2a15c4f2"
client_secret = "9ce3301ea98a4bd687364c886baa15de"

# %%
class SporifyAPI:
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
        
    def get_client_credentials(self):
        """
        Returns a base64 encoded string.
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception("You must set client_id and client_secret")
        
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}" # <base64 encoded client_id:client_secret>
        }
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        }
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        token_response_data = r.json()
        if r.status_code not in range(200, 299):
            raise Exception("Could not authenticate client")
        data = r.json()
        now = datetime.datetime.now()
        access_token = data["access_token"]
        expires_in = token_response_data["expires_in"] # seconds
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token() 
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
    
    def get_resource(self, lookup_id, resource_type="albums", version="v1"):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def search(self, query, search_type="artist"):
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        data = urlencode({"q": query, "type": search_type.lower()})
        lookup_url = f"{endpoint}?{data}"
        print(lookup_url)
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()

# %%
client = SporifyAPI(client_id, client_secret)

# %%
client.search("watch the throne", search_type="album")
# Out:
# https://api.spotify.com/v1/search?q=watch+the+throne&type=album
# {'albums': {'href': 'https://api.spotify.com/v1/search?query=watch+the+throne&type=album&offset=0&limit=20',
#   'items': [{'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nFkdlSjzX9mRTtwJOzDYB'},
#       'href': 'https://api.spotify.com/v1/artists/3nFkdlSjzX9mRTtwJOzDYB',
#       'id': '3nFkdlSjzX9mRTtwJOzDYB',
#       'name': 'JAY-Z',
#       'type': 'artist',
#       'uri': 'spotify:artist:3nFkdlSjzX9mRTtwJOzDYB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2P2Xwvh2xWXIZ1OWY9S9o5'},
#     'href': 'https://api.spotify.com/v1/albums/2P2Xwvh2xWXIZ1OWY9S9o5',
#     'id': '2P2Xwvh2xWXIZ1OWY9S9o5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734a767758e8ebe2443591c9fd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024a767758e8ebe2443591c9fd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514a767758e8ebe2443591c9fd',
#       'width': 64}],
#     'name': 'Watch The Throne (Deluxe)',
#     'release_date': '2011-08-08',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:2P2Xwvh2xWXIZ1OWY9S9o5'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nFkdlSjzX9mRTtwJOzDYB'},
#       'href': 'https://api.spotify.com/v1/artists/3nFkdlSjzX9mRTtwJOzDYB',
#       'id': '3nFkdlSjzX9mRTtwJOzDYB',
#       'name': 'JAY-Z',
#       'type': 'artist',
#       'uri': 'spotify:artist:3nFkdlSjzX9mRTtwJOzDYB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['CA', 'JP', 'MX', 'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7mCeLbChyegbRwwKK5shJs'},
#     'href': 'https://api.spotify.com/v1/albums/7mCeLbChyegbRwwKK5shJs',
#     'id': '7mCeLbChyegbRwwKK5shJs',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bf2d62374f877d312b34e67a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bf2d62374f877d312b34e67a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bf2d62374f877d312b34e67a',
#       'width': 64}],
#     'name': 'Watch The Throne',
#     'release_date': '2011-08-08',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:7mCeLbChyegbRwwKK5shJs'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3eDaTLMkzYIUdwiyVn2tsy'},
#       'href': 'https://api.spotify.com/v1/artists/3eDaTLMkzYIUdwiyVn2tsy',
#       'id': '3eDaTLMkzYIUdwiyVn2tsy',
#       'name': 'Keykodez',
#       'type': 'artist',
#       'uri': 'spotify:artist:3eDaTLMkzYIUdwiyVn2tsy'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3y5AiOyWyOPPYV4GaJFGX5'},
#     'href': 'https://api.spotify.com/v1/albums/3y5AiOyWyOPPYV4GaJFGX5',
#     'id': '3y5AiOyWyOPPYV4GaJFGX5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732ea9018c29cfe113a4e23933',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022ea9018c29cfe113a4e23933',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512ea9018c29cfe113a4e23933',
#       'width': 64}],
#     'name': 'Watch the Throne',
#     'release_date': '2020-01-03',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3y5AiOyWyOPPYV4GaJFGX5'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nFkdlSjzX9mRTtwJOzDYB'},
#       'href': 'https://api.spotify.com/v1/artists/3nFkdlSjzX9mRTtwJOzDYB',
#       'id': '3nFkdlSjzX9mRTtwJOzDYB',
#       'name': 'JAY-Z',
#       'type': 'artist',
#       'uri': 'spotify:artist:3nFkdlSjzX9mRTtwJOzDYB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['AE',
#      'BH',
#      'BY',
#      'CA',
#      'DZ',
#      'EG',
#      'FR',
#      'ID',
#      'IN',
#      'JO',
#      'KW',
#      'KZ',
#      'LB',
#      'MA',
#      'MX',
#      'MY',
#      'OM',
#      'PL',
#      'PS',
#      'QA',
#      'RU',
#      'SA',
#      'TN',
#      'TR',
#      'UA',
#      'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6Oa0ZYzr4VdFIz3zNmYJYQ'},
#     'href': 'https://api.spotify.com/v1/albums/6Oa0ZYzr4VdFIz3zNmYJYQ',
#     'id': '6Oa0ZYzr4VdFIz3zNmYJYQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d2801f96923ebab452baa232',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d2801f96923ebab452baa232',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d2801f96923ebab452baa232',
#       'width': 64}],
#     'name': 'Watch The Throne',
#     'release_date': '2011-08-08',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:6Oa0ZYzr4VdFIz3zNmYJYQ'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nFkdlSjzX9mRTtwJOzDYB'},
#       'href': 'https://api.spotify.com/v1/artists/3nFkdlSjzX9mRTtwJOzDYB',
#       'id': '3nFkdlSjzX9mRTtwJOzDYB',
#       'name': 'JAY-Z',
#       'type': 'artist',
#       'uri': 'spotify:artist:3nFkdlSjzX9mRTtwJOzDYB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['AE',
#      'AU',
#      'BH',
#      'DZ',
#      'EG',
#      'ES',
#      'FR',
#      'HU',
#      'IS',
#      'JO',
#      'KW',
#      'LB',
#      'MA',
#      'MX',
#      'MY',
#      'NO',
#      'OM',
#      'PH',
#      'PL',
#      'PT',
#      'QA',
#      'SA',
#      'TN',
#      'TR',
#      'US',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2IC7s3KVP6ottxQUnkm4eS'},
#     'href': 'https://api.spotify.com/v1/albums/2IC7s3KVP6ottxQUnkm4eS',
#     'id': '2IC7s3KVP6ottxQUnkm4eS',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273940bc47d2136cc141eda6193',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02940bc47d2136cc141eda6193',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851940bc47d2136cc141eda6193',
#       'width': 64}],
#     'name': 'Watch The Throne (Deluxe)',
#     'release_date': '2011-08-08',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:2IC7s3KVP6ottxQUnkm4eS'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5LbqEj6luP2V7UhLSXyVUz'},
#       'href': 'https://api.spotify.com/v1/artists/5LbqEj6luP2V7UhLSXyVUz',
#       'id': '5LbqEj6luP2V7UhLSXyVUz',
#       'name': 'Dillihano',
#       'type': 'artist',
#       'uri': 'spotify:artist:5LbqEj6luP2V7UhLSXyVUz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/79f6yGrkFzXLZZbTZrUGPm'},
#     'href': 'https://api.spotify.com/v1/albums/79f6yGrkFzXLZZbTZrUGPm',
#     'id': '79f6yGrkFzXLZZbTZrUGPm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b74cc4353924749a190e6690',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b74cc4353924749a190e6690',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b74cc4353924749a190e6690',
#       'width': 64}],
#     'name': 'I Watch the Throne II (The Mental Lap)',
#     'release_date': '2020-03-03',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:79f6yGrkFzXLZZbTZrUGPm'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0d8mG9WdaERsqUDE3HfZUz'},
#       'href': 'https://api.spotify.com/v1/artists/0d8mG9WdaERsqUDE3HfZUz',
#       'id': '0d8mG9WdaERsqUDE3HfZUz',
#       'name': 'Tore Oellingrath',
#       'type': 'artist',
#       'uri': 'spotify:artist:0d8mG9WdaERsqUDE3HfZUz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3d2jE72XH1BUHjPE4UvGw0'},
#       'href': 'https://api.spotify.com/v1/artists/3d2jE72XH1BUHjPE4UvGw0',
#       'id': '3d2jE72XH1BUHjPE4UvGw0',
#       'name': 'El Kezz',
#       'type': 'artist',
#       'uri': 'spotify:artist:3d2jE72XH1BUHjPE4UvGw0'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1gy54pmSWyGXZTTImVAA20'},
#     'href': 'https://api.spotify.com/v1/albums/1gy54pmSWyGXZTTImVAA20',
#     'id': '1gy54pmSWyGXZTTImVAA20',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ccc139d3070b51069e03041a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ccc139d3070b51069e03041a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ccc139d3070b51069e03041a',
#       'width': 64}],
#     'name': 'Du Vil Meg (Watch the Throne 2021)',
#     'release_date': '2020-06-14',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1gy54pmSWyGXZTTImVAA20'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nFkdlSjzX9mRTtwJOzDYB'},
#       'href': 'https://api.spotify.com/v1/artists/3nFkdlSjzX9mRTtwJOzDYB',
#       'id': '3nFkdlSjzX9mRTtwJOzDYB',
#       'name': 'JAY-Z',
#       'type': 'artist',
#       'uri': 'spotify:artist:3nFkdlSjzX9mRTtwJOzDYB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['AD',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'KZ',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'RO',
#      'RS',
#      'RU',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0OcMap99vLEeGkBCfCwRwS'},
#     'href': 'https://api.spotify.com/v1/albums/0OcMap99vLEeGkBCfCwRwS',
#     'id': '0OcMap99vLEeGkBCfCwRwS',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27352e61456aa4995ba48d94e30',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0252e61456aa4995ba48d94e30',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485152e61456aa4995ba48d94e30',
#       'width': 64}],
#     'name': 'Watch The Throne',
#     'release_date': '2011-08-08',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0OcMap99vLEeGkBCfCwRwS'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nFkdlSjzX9mRTtwJOzDYB'},
#       'href': 'https://api.spotify.com/v1/artists/3nFkdlSjzX9mRTtwJOzDYB',
#       'id': '3nFkdlSjzX9mRTtwJOzDYB',
#       'name': 'JAY-Z',
#       'type': 'artist',
#       'uri': 'spotify:artist:3nFkdlSjzX9mRTtwJOzDYB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['CA', 'JP', 'MX', 'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4P63UgNDUcF11MnWzyvVrh'},
#     'href': 'https://api.spotify.com/v1/albums/4P63UgNDUcF11MnWzyvVrh',
#     'id': '4P63UgNDUcF11MnWzyvVrh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a0e1044519b4da374703952',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a0e1044519b4da374703952',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a0e1044519b4da374703952',
#       'width': 64}],
#     'name': 'Watch The Throne (Deluxe)',
#     'release_date': '2011-08-08',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:4P63UgNDUcF11MnWzyvVrh'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2v4JjFwbhEkHnXQdMPpyon'},
#       'href': 'https://api.spotify.com/v1/artists/2v4JjFwbhEkHnXQdMPpyon',
#       'id': '2v4JjFwbhEkHnXQdMPpyon',
#       'name': 'Lucky Luciano',
#       'type': 'artist',
#       'uri': 'spotify:artist:2v4JjFwbhEkHnXQdMPpyon'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIcSZlwRxIF6gPgtwSrbq'},
#       'href': 'https://api.spotify.com/v1/artists/4VIcSZlwRxIF6gPgtwSrbq',
#       'id': '4VIcSZlwRxIF6gPgtwSrbq',
#       'name': 'Dat Boi T',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VIcSZlwRxIF6gPgtwSrbq'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6JoX770NDDxQ8HK01lADMG'},
#     'href': 'https://api.spotify.com/v1/albums/6JoX770NDDxQ8HK01lADMG',
#     'id': '6JoX770NDDxQ8HK01lADMG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27340caf1335f465d52f9082092',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0240caf1335f465d52f9082092',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485140caf1335f465d52f9082092',
#       'width': 64}],
#     'name': 'Thoed Essays 3: Watch the Latin Throne',
#     'release_date': '2013-01-17',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:6JoX770NDDxQ8HK01lADMG'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3nFkdlSjzX9mRTtwJOzDYB'},
#       'href': 'https://api.spotify.com/v1/artists/3nFkdlSjzX9mRTtwJOzDYB',
#       'id': '3nFkdlSjzX9mRTtwJOzDYB',
#       'name': 'JAY-Z',
#       'type': 'artist',
#       'uri': 'spotify:artist:3nFkdlSjzX9mRTtwJOzDYB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5K4W6rqBFWDnAN6FQUkS6x'},
#       'href': 'https://api.spotify.com/v1/artists/5K4W6rqBFWDnAN6FQUkS6x',
#       'id': '5K4W6rqBFWDnAN6FQUkS6x',
#       'name': 'Kanye West',
#       'type': 'artist',
#       'uri': 'spotify:artist:5K4W6rqBFWDnAN6FQUkS6x'}],
#     'available_markets': ['CA',
#      'CR',
#      'DO',
#      'GT',
#      'HN',
#      'JP',
#      'MX',
#      'NI',
#      'PA',
#      'SV',
#      'US'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0eZRIt3Ht1IuMXsr0QR8OY'},
#     'href': 'https://api.spotify.com/v1/albums/0eZRIt3Ht1IuMXsr0QR8OY',
#     'id': '0eZRIt3Ht1IuMXsr0QR8OY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d3002b1a44e2a79abde59556',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d3002b1a44e2a79abde59556',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d3002b1a44e2a79abde59556',
#       'width': 64}],
#     'name': 'Watch The Throne',
#     'release_date': '2011-08-08',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0eZRIt3Ht1IuMXsr0QR8OY'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ZBnvCszokLW4YHZ50uHY8'},
#       'href': 'https://api.spotify.com/v1/artists/6ZBnvCszokLW4YHZ50uHY8',
#       'id': '6ZBnvCszokLW4YHZ50uHY8',
#       'name': 'Chuuwee',
#       'type': 'artist',
#       'uri': 'spotify:artist:6ZBnvCszokLW4YHZ50uHY8'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/60HQTq8ZavGJGksZsWiImY'},
#     'href': 'https://api.spotify.com/v1/albums/60HQTq8ZavGJGksZsWiImY',
#     'id': '60HQTq8ZavGJGksZsWiImY',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ff75398372dab9a65d44fc0e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ff75398372dab9a65d44fc0e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ff75398372dab9a65d44fc0e',
#       'width': 64}],
#     'name': 'Watching The Throne',
#     'release_date': '2018-07-26',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:60HQTq8ZavGJGksZsWiImY'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3LRldYGJpCAQT5cZKQyi7o'},
#       'href': 'https://api.spotify.com/v1/artists/3LRldYGJpCAQT5cZKQyi7o',
#       'id': '3LRldYGJpCAQT5cZKQyi7o',
#       'name': 'Hannah Peel',
#       'type': 'artist',
#       'uri': 'spotify:artist:3LRldYGJpCAQT5cZKQyi7o'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6K0BxMny2XYSAnl0DYTNQd'},
#     'href': 'https://api.spotify.com/v1/albums/6K0BxMny2XYSAnl0DYTNQd',
#     'id': '6K0BxMny2XYSAnl0DYTNQd',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273786d331ab6976253cf98e5a8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02786d331ab6976253cf98e5a8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851786d331ab6976253cf98e5a8',
#       'width': 64}],
#     'name': 'Game of Thrones: The Last Watch (Music from the HBO Documentary)',
#     'release_date': '2019-10-07',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:6K0BxMny2XYSAnl0DYTNQd'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7nLs3HSxHFQ01uitTlDM29'},
#       'href': 'https://api.spotify.com/v1/artists/7nLs3HSxHFQ01uitTlDM29',
#       'id': '7nLs3HSxHFQ01uitTlDM29',
#       'name': 'JB Daniels',
#       'type': 'artist',
#       'uri': 'spotify:artist:7nLs3HSxHFQ01uitTlDM29'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/11TFXpRdlT3cYacABtOjP0'},
#     'href': 'https://api.spotify.com/v1/albums/11TFXpRdlT3cYacABtOjP0',
#     'id': '11TFXpRdlT3cYacABtOjP0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27319f6daf2d632e3556fb2908e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0219f6daf2d632e3556fb2908e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485119f6daf2d632e3556fb2908e',
#       'width': 64}],
#     'name': 'Watch the Throne',
#     'release_date': '2020-06-12',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:11TFXpRdlT3cYacABtOjP0'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4ry9Eb2VVXWqYEnswMvOJW'},
#       'href': 'https://api.spotify.com/v1/artists/4ry9Eb2VVXWqYEnswMvOJW',
#       'id': '4ry9Eb2VVXWqYEnswMvOJW',
#       'name': 'Maverick',
#       'type': 'artist',
#       'uri': 'spotify:artist:4ry9Eb2VVXWqYEnswMvOJW'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/19w3E1hLxkhgTng32dtw0x'},
#     'href': 'https://api.spotify.com/v1/albums/19w3E1hLxkhgTng32dtw0x',
#     'id': '19w3E1hLxkhgTng32dtw0x',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27341df7f39d3054188fa6ed21b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0241df7f39d3054188fa6ed21b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485141df7f39d3054188fa6ed21b',
#       'width': 64}],
#     'name': 'Watch the Throne',
#     'release_date': '2019-09-30',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:19w3E1hLxkhgTng32dtw0x'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4LjZnzfcR7EgcLlpRWaFiw'},
#       'href': 'https://api.spotify.com/v1/artists/4LjZnzfcR7EgcLlpRWaFiw',
#       'id': '4LjZnzfcR7EgcLlpRWaFiw',
#       'name': 'Kontrabandz',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LjZnzfcR7EgcLlpRWaFiw'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1VJcALVgWBkwXLnYvdgMoH'},
#     'href': 'https://api.spotify.com/v1/albums/1VJcALVgWBkwXLnYvdgMoH',
#     'id': '1VJcALVgWBkwXLnYvdgMoH',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273da3e89a13c4f7a8eefd4398e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02da3e89a13c4f7a8eefd4398e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851da3e89a13c4f7a8eefd4398e',
#       'width': 64}],
#     'name': 'Watch the Throne',
#     'release_date': '2019-04-23',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:1VJcALVgWBkwXLnYvdgMoH'},
#    {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1NbtUh6dWXTbHnd0Glkl1h'},
#       'href': 'https://api.spotify.com/v1/artists/1NbtUh6dWXTbHnd0Glkl1h',
#       'id': '1NbtUh6dWXTbHnd0Glkl1h',
#       'name': 'Rue Royal',
#       'type': 'artist',
#       'uri': 'spotify:artist:1NbtUh6dWXTbHnd0Glkl1h'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2iBEKNMLSeYMXdtxR10Esi'},
#     'href': 'https://api.spotify.com/v1/albums/2iBEKNMLSeYMXdtxR10Esi',
#     'id': '2iBEKNMLSeYMXdtxR10Esi',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738b40b268a7cc837c7978c471',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028b40b268a7cc837c7978c471',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518b40b268a7cc837c7978c471',
#       'width': 64}],
#     'name': 'Watch the Throne',
#     'release_date': '2020-07-15',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
#     'type': 'album',
#     'uri': 'spotify:album:2iBEKNMLSeYMXdtxR10Esi'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Vab10LaoVqib7E72YlG9M'},
#       'href': 'https://api.spotify.com/v1/artists/4Vab10LaoVqib7E72YlG9M',
#       'id': '4Vab10LaoVqib7E72YlG9M',
#       'name': 'Midnight Hustle',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Vab10LaoVqib7E72YlG9M'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3vKxRSKVap50HXbs4HL6my'},
#     'href': 'https://api.spotify.com/v1/albums/3vKxRSKVap50HXbs4HL6my',
#     'id': '3vKxRSKVap50HXbs4HL6my',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6585756f4979a9c0a3353cd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6585756f4979a9c0a3353cd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6585756f4979a9c0a3353cd',
#       'width': 64}],
#     'name': 'Watch the Throne',
#     'release_date': '2020-06-21',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3vKxRSKVap50HXbs4HL6my'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/49uxHmW6pq3AInVeGbzHgx'},
#       'href': 'https://api.spotify.com/v1/artists/49uxHmW6pq3AInVeGbzHgx',
#       'id': '49uxHmW6pq3AInVeGbzHgx',
#       'name': 'Supreme Naim',
#       'type': 'artist',
#       'uri': 'spotify:artist:49uxHmW6pq3AInVeGbzHgx'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6FQzdKeUilRMhzAGumRC7w'},
#     'href': 'https://api.spotify.com/v1/albums/6FQzdKeUilRMhzAGumRC7w',
#     'id': '6FQzdKeUilRMhzAGumRC7w',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27365ed776f7316b22c8e6c8e16',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0265ed776f7316b22c8e6c8e16',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485165ed776f7316b22c8e6c8e16',
#       'width': 64}],
#     'name': 'Watch the Throne',
#     'release_date': '2019-02-18',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6FQzdKeUilRMhzAGumRC7w'},
#    {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3vI7NAhZQpq3MOXVt7kLnQ'},
#       'href': 'https://api.spotify.com/v1/artists/3vI7NAhZQpq3MOXVt7kLnQ',
#       'id': '3vI7NAhZQpq3MOXVt7kLnQ',
#       'name': 'K-YO',
#       'type': 'artist',
#       'uri': 'spotify:artist:3vI7NAhZQpq3MOXVt7kLnQ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6JyaZnvNIhsUYlfqTJKPSy'},
#     'href': 'https://api.spotify.com/v1/albums/6JyaZnvNIhsUYlfqTJKPSy',
#     'id': '6JyaZnvNIhsUYlfqTJKPSy',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737876f4af87f9c99a2894ba20',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027876f4af87f9c99a2894ba20',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517876f4af87f9c99a2894ba20',
#       'width': 64}],
#     'name': 'Watch the Throne',
#     'release_date': '2016',
#     'release_date_precision': 'year',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6JyaZnvNIhsUYlfqTJKPSy'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=watch+the+throne&type=album&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 35}}

# %%
 client.get_artist("3nFkdlSjzX9mRTtwJOzDYB")
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3nFkdlSjzX9mRTtwJOzDYB'},
#  'followers': {'href': None, 'total': 5521359},
#  'genres': ['east coast hip hop', 'hip hop', 'pop rap', 'rap'],
#  'href': 'https://api.spotify.com/v1/artists/3nFkdlSjzX9mRTtwJOzDYB',
#  'id': '3nFkdlSjzX9mRTtwJOzDYB',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/4912d27d6b01dd790313d8ef76586be6b100550f',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/027c5605d895158497ff377d92d69fe89dba1730',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/1420226e471d0e56ae4de7cb28ba2eb4de0a29ce',
#    'width': 160}],
#  'name': 'JAY-Z',
#  'popularity': 85,
#  'type': 'artist',
#  'uri': 'spotify:artist:3nFkdlSjzX9mRTtwJOzDYB'}

# %%
client.get_album('')
